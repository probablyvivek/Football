# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Arc
import numpy as np
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
#read data from a file
import pandas as pd
df = pd.read_excel('data.xlsx')
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
df.head()
# Out:
#    series_id                   series_name  match_id  match_no  \
# 0        259  Indian Super League, 2021-22     43140  Match 41
# 1        259  Indian Super League, 2021-22     43140  Match 41
# 2        259  Indian Super League, 2021-22     43140  Match 41
# 3        259  Indian Super League, 2021-22     43140  Match 41
# 4        259  Indian Super League, 2021-22     43140  Match 41
#
#         matchdate_gmt  team_id           team_name  Player_id  \
# 0 2021-12-26 14:00:00     1159       Jamshedpur FC     112642
# 1 2021-12-26 14:00:00      498  Kerala Blasters FC       6079
# 2 2021-12-26 14:00:00      498  Kerala Blasters FC      23842
# 3 2021-12-26 14:00:00     1159       Jamshedpur FC      21605
# 4 2021-12-26 14:00:00      498  Kerala Blasters FC      35321
#
#                   Player_Name  x_coord  y_coord  event_id event_name  rnk  \
# 0               Jordan Murray    27.65    11.92        10    Offside    1
# ...

# %%
#Select the following columns from the dataframe and store it in a new dataframe called df2 : team_name, Player_Name, event_name, half, flipped_x_coord, flipped_y_coord, direction, minutes, seconds
df2 = df[['team_name', 'Player_Name', 'event_name', 'half', 'flipped_x_coord', 'flipped_y_coord', 'direction', 'minutes', 'seconds']]

# %%
#Change column name flipped_x_coord to X and flipped_y_coord to Y
df2.rename(columns={'flipped_x_coord':'x', 'flipped_y_coord':'y', 'event_name':'result'}, inplace=True)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
#Filter out data where the event_name is not a Shot or Shot on Goal or Goal
df2 = df2[df2['result'].isin(['Shot', 'Shot on Goal', 'Goal'])]

# %%
df2
# Out:
#               team_name                   Player_Name        result  half  \
# 12        Jamshedpur FC  Greg Alexander James Stewart  Shot on Goal     1
# 13        Jamshedpur FC  Greg Alexander James Stewart  Shot on Goal     1
# 20        Jamshedpur FC          Boris Singh Thangjam          Shot     1
# 24        Jamshedpur FC          Boris Singh Thangjam          Shot     1
# 25        Jamshedpur FC         Peter William Hartley          Shot     1
# 30        Jamshedpur FC  Greg Alexander James Stewart  Shot on Goal     1
# 31        Jamshedpur FC  Greg Alexander James Stewart          Goal     1
# 47   Kerala Blasters FC         Alvaro Vazquez Garcia  Shot on Goal     1
# 48   Kerala Blasters FC         Alvaro Vazquez Garcia  Shot on Goal     1
# 49   Kerala Blasters FC             Sahal Abdul Samad  Shot on Goal     1
# 50   Kerala Blasters FC             Sahal Abdul Samad          Goal     1
# 51   Kerala Blasters FC             Sahal Abdul Samad          Goal     1
# ...

# %%
hteam = df2['team_name'].iloc[0]
ateam = df2['team_name'].iloc[-1]

# %%
def createPitch():
    # Create figure
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    plt.axis([0,105, 70,0])

    plt.plot([3.66,3.66], [3.66,67], color='black')
    plt.plot([3.66, 100.85], [67,67], color = 'black')
    plt.plot([3.66,100.85], [3.66,3.66], color = 'black')
    plt.plot([100.85, 100.85], [67,3.66], color ='black')
    plt.plot([52.26, 52.26], [67,3.66], color='black')

    #Right-side penalty Box
    plt.plot([84.24,100.85],[53.60,53.60], color= 'black')
    plt.plot([84.24,100.85],[15.42,15.42], color ='black')
    plt.plot([84.24, 84.24],[15.42, 53.60], color = 'black')
    plt.plot([96.45, 96.45], [25.45, 43.57], color='black')
    plt.plot([96.45, 100.85], [43.57, 43.57], color='black')
    plt.plot([96.45, 100.85], [25.45, 25.45], color='black')

    #left-side penalty box
    plt.plot([3.66,20.27], [53.60, 53.60], color= 'black')
    plt.plot([20.27, 20.27], [15.42,53.60], color= 'black')
    plt.plot([3.66, 20.27], [15.42, 15.42], color = 'black')
    plt.plot([3.66, 8.06], [43.57, 43.57], color='black')
    plt.plot([8.06, 8.06], [25.45, 43.57], color='black')
    plt.plot([3.66, 8.06], [25.45, 25.45], color='black')

    #penalty spots
    leftPenalty = plt.Circle((91,34.51), 0.5)
    rightPenalty = plt.Circle((13.51,34.51), 0.5)


    #Arcs
    leftArc = Arc((14.385,34.51),height=18.3,width=20.5,angle=0,theta1=308.15,theta2=51.85,color="black")
    rightArc = Arc((90.385, 34.51), height=18.3,width=20.5, angle=0, theta1=130, theta2=230, color='black')

    #CentreCircle points
    centreCircle = plt.Circle((52.26, 34.51), 9.06, fill=False)
    centrePoint = plt.Circle((52.26,34.51), 0.8)

    ax.add_patch(centreCircle)
    ax.add_patch(centrePoint)
    ax.add_patch(leftPenalty)
    ax.add_patch(rightPenalty)
    ax.add_patch(leftArc)
    ax.add_patch(rightArc)
    ax.axis('off')
