# %%
from griffis_soccer_analysis.fbref_code import *
from griffis_soccer_analysis.similarity import *
from griffis_soccer_analysis.whoscored_match_report import *
from PIL import Image
import ssl
import urllib.request

# Bypass SSL verification
ssl._create_default_https_context = ssl._create_unverified_context

# %%
whoscored_match_report(
    # The URL of the Whoscored match (detailed tournaments only)
    url='https://www.whoscored.com/Matches/1787315/Live/International-European-Championship-Germany-Scotland',
    # The match name
    match='Germany 5-1 Scotland',
    
    # Home team name
    team_h='Germany',
    # Whoscored's ID for the home team (can find in the HTML slug of the team's page)
    teamId_h=336,
    
    # Away team name
    team_a='Scotland',
    # Away team ID
    teamId_a=424,
    
    # League name
    lg='European Championships',
    # Game date
    date='June 14, 2024',
    # Your signature
    sig='@VisualizeTrends',
    # Language for the image (English, Spanish, Portuguese, French)
    language='English',
    
    # Location of your Chromedriver
    chrome_driver_loc='/Users/vivektiwari/Downloads/chromedriver',
    # Where you want the data to download to
    data_download_loc='/Users/vivektiwari/Downloads',
    
    # Where you want the final image to export to
    img_save_loc='/Users/vivektiwari/Downloads',
    # Path to home team's image
    home_img='/Users/vivektiwari/Downloads/Germany.png',
    # Path to away team's image
    away_img='/Users/vivektiwari/Downloads/Scotland.png'
)
# Out:
# <PIL.Image.Image image mode=RGB size=1737x2026>
