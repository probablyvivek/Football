# %%
import sys
sys.path.append('./src')  
import ScraperFC as sfc

# %%
tm = sfc.Transfermarkt()
players = tm.scrape_players("24/25", "EPL")
players.head()
# Out:
# 24/25 EPL player links: 100%|██████████| 20/20 [00:50<00:00,  2.53s/it]
# 24/25 EPL players: 100%|██████████| 1180/1180 [24:34<00:00,  1.25s/it]
#                Name    Value Value last updated           DOB Age Height (m)  \
# 0      Andrew Moran   €3.00m       May 24, 2024  Oct 15, 2003  20       1.77
# 1     Sandro Tonali  €38.00m       May 27, 2024   May 8, 2000  24       1.81
# 2     Rodrigo Gomes  €12.00m        Jun 6, 2024   Jul 7, 2003  21       1.75
# 3       Luke Harris   €1.00m       Dec 19, 2023   Mar 4, 2005  19       1.77
# 4  Timothy Castagne  €17.00m       May 27, 2024   Dec 5, 1995  28       1.85
#
#   Nationality Citizenship            Position  \
# 0     Ireland          []  Attacking Midfield
# 1       Italy          []  Defensive Midfield
# 2    Portugal          []          Right-Back
# 3       Wales          []  Attacking Midfield
# 4     Belgium   [Belgium]          Right-Back
#
#                                      Other positions       Team Last club  \
# 0                                               None   Brighton      None
# 1                                               None  Newcastle      None
# 2                                               None     Wolves      None
# 3                                               None     Fulham      None
# 4                  0
# 0  Right Midfield
# 1       Le...     Fulham      None
#
#   Since        Joined Contract expiration Market value history  \
# 0  None   Jul 1, 2023        Jun 30, 2027                 None
# 1  None   Jul 3, 2023        Jun 30, 2028                 None
# 2  None   Jul 1, 2024        Jun 30, 2029                 None
# 3  None   Jul 1, 2023        Jun 30, 2026                 None
# 4  None  Aug 29, 2023        Jun 30, 2027                 None
#
#                                     Transfer history
# 0  Empty DataFrame
# Columns: [Season, Date, Left, ...
# 1  Empty DataFrame
# Columns: [Season, Date, Left, ...
# 2  Empty DataFrame
# Columns: [Season, Date, Left, ...
# 3  Empty DataFrame
# Columns: [Season, Date, Left, ...
# 4  Empty DataFrame
# Columns: [Season, Date, Left, ...

# %%
players.to_csv("players.csv")
